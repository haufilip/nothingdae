# %% [markdown]
# # ⛛ Quantum Snake
#
# A classic Snake game fused with quantum mechanics power-ups!
#
# ## How to Play
# - **Run the cell below**, then **click the canvas** to focus it
# - **Arrow Keys** — steer the main (green) snake
# - **WASD** — steer the second (orange) snake when Papaya is active
#
# ## Quantum Power-ups
#
# | Fruit | Quantum Effect | Duration |
# |-------|---------------|----------|
# | 🍎 **Apple** | **Entanglement** — A ghost snake spawns at the mirrored position and moves in the opposite direction. Both snakes share a quantum link and can eat fruit together. | 10 s |
# | 🍇 **Grape** | **Quantum Tunneling** — Your snake passes through walls (appearing on the other side) **and** phases through its own body without dying. | 10 s |
# | 🥭 **Papaya** | **Dual Snake** — A second orange snake spawns that you control with WASD simultaneously. It can collect its own power-ups! | 10 s |
#
# > **Tip:** Hitting yourself or the second snake still ends the game unless Grape tunneling is active!

# %%
import base64
from IPython.display import HTML

# Run this cell to launch Quantum Snake!
_html_b64 = "..."
_html = base64.b64decode(_html_b64).decode('utf-8')
HTML(_html)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="UTF-8">
# <style>
#   * { box-sizing: border-box; margin: 0; padding: 0; }
#   body {
#     background: #060612;
#     display: flex;
#     flex-direction: column;
#     align-items: center;
#     padding: 12px 8px 16px;
#     font-family: 'Courier New', monospace;
#     color: #c0c8ff;
#     user-select: none;
#   }
#   h1 {
#     font-size: 22px;
#     letter-spacing: 3px;
#     color: #9090ff;
#     margin-bottom: 10px;
#     text-shadow: 0 0 20px #5050cc;
#   }
#   #hud {
#     display: flex;
#     gap: 14px;
#     margin-bottom: 10px;
#     font-size: 13px;
#     align-items: center;
#     flex-wrap: wrap;
#     justify-content: center;
#   }
#   .score-box { font-size: 16px; color: #fff; }
#   .badge {
#     padding: 3px 12px;
#     border-radius: 20px;
#     font-size: 11px;
#     font-weight: bold;
#     display: none;
#   }
#   #b-entangle { background: linear-gradient(90deg,#800,#c00); color:#fcc; border:1px solid #f44; }
# ...
